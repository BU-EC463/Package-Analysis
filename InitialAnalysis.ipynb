# %% [markdown]
# ## Input Data Cleaning and Drug Similarity Calculation

# %%
import pandas as pd
import numpy as np


def CleanData(file_path):
    # Reading the file

    # Load the data from the CSV file
    data = pd.read_csv(file_path)

    # Removing the specified columns and reordering the 'Item Number – 8 digit' column
    columns_to_remove = ['Item Number – 6 digit', 'UPC Number', 'Constant', 
                        'Customer-Specific Item Number', 'Pack Size Divisor', 
                        'RX/OTC Indicator']

    # Removing the columns
    data_cleaned = data.drop(columns=columns_to_remove)

    # Reordering 'Item Number – 8 digit' to the left
    column_to_move = data_cleaned.pop('Item Number – 8 digit')
    data_cleaned.insert(0, 'Item Number – 8 digit', column_to_move)

    # Moving all price columns and the contract flag to the right
    columns_to_move = ['AWP Price', 'Acquisition Price', 'Retail Price', 'WAC Price', 'Contract Flag']
    for col in columns_to_move:
        data_cleaned[col] = data_cleaned.pop(col)

    import re

    # Function to split the generic description into generic name and form
    def split_description(desc):
        match = re.search(r'[A-Z]', desc)
        if match:
            index = match.start()
            return desc[:index].strip(), desc[index:].strip()
        else:
            return desc, ''

    # Applying the function to split 'Generic Description'
    data_cleaned['Generic Name'], data_cleaned['Form'] = zip(*data_cleaned['Generic Description'].apply(split_description))
    data_cleaned.drop(columns=['Generic Description'], inplace=True)

    # Removing rows where 'Generic Name' is empty or whitespace
    data_cleaned = data_cleaned[data_cleaned['Generic Name'].str.strip() != '']

    # Function to split the description into name and size
    def split_description_on_number(desc):
        match = re.search(r'\d', desc)
        if match:
            index = match.start()
            return desc[:index].strip(), desc[index:].strip()
        else:
            return desc, ''

    # Applying the function to split 'Description'
    data_cleaned['Name'], data_cleaned['Size'] = zip(*data_cleaned['Description'].apply(split_description_on_number))
    data_cleaned.drop(columns=['Description'], inplace=True)

    data_cleaned
    return data_cleaned

# %%
def ExactDrugAlgoFunction(drug_code, data):
    # Item number of the drug to run the similarity test on
    reference_item_number = drug_code

    # Find and print the row for the given reference_item_number
    matching_row = data[data['Item Number – 8 digit'] == reference_item_number]
    

    # Find the Generic Name for the given reference_item_number
    reference_generic_name = data.loc[data['Item Number – 8 digit'] == reference_item_number, 'Generic Name'].iloc[0]


    # Create a copy of the dataframe filtered by Generic Name
    data_generic = data[data['Generic Name'] == reference_generic_name].copy()

    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity

    # Selecting the reference item
    reference_item = data_generic[data_generic['Item Number – 8 digit'] == reference_item_number]
    if reference_item.empty:
        return "Reference item not found in the dataset."

    # Extracting the form of the reference item
    reference_form = reference_item.iloc[0]['Form']
    forms = data_generic['Form'].tolist()
    forms.insert(0, reference_form)

    # Vectorizing the forms using TF-IDF
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(forms)

    # Calculating cosine similarity
    cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:]).flatten()
    data_generic['Similarity'] = cosine_similarities

    # Filtering the dataset to show only items with a similarity score above 0.9
    similarity_items = data_generic[data_generic['Similarity'] > 0].copy()

    # Extracting the size of the reference item
    reference_size = reference_item.iloc[0]['Size']
    sizes = similarity_items['Size'].tolist()
    sizes.insert(0, reference_size)

    # Vectorizing the sizes using TF-IDF
    tfidf_matrix_sizes = vectorizer.fit_transform(sizes)

    # Calculating cosine similarity for sizes
    cosine_similarities_sizes = cosine_similarity(tfidf_matrix_sizes[0:1], tfidf_matrix_sizes[1:]).flatten()
    similarity_items['Size Similarity'] = cosine_similarities_sizes

    # Remove input item
    similarity_items = similarity_items[similarity_items['Item Number – 8 digit'] != reference_item_number]

    # Define true similarity
    w1 = 1
    w2 = 1
    similarity_items['True Similarity'] = (w1 * similarity_items['Similarity'] + w2 * similarity_items['Size Similarity']) / (w1 + w2)

    # Cleaning and sort the data
    similarity_items = similarity_items.drop(columns=['Similarity', 'Size Similarity'])
    similarity_items = similarity_items.sort_values(by=['True Similarity'], ascending=False)
    
    
    return similarity_items, matching_row

# %%
inputData = CleanData('Daily Snapshot.csv')
data, input = ExactDrugAlgoFunction(10228908, inputData)

inputData.head(10)
# data.head(10)
# Out:
#     Item Number – 8 digit   NDC Number  Size Qty  Retail Pack Quantity  \
# 0                10000009  51672408306  45                           1
# 1                10083412  00023334807                               1
# 2                10000013  00093227234  20                           1
# 3                10083430  51991062033  30                           1
# 5                10083433  67457022005  6X5                          1
# 6                10000077  00003161112  30                           1
# 7                10000082  00003161212  30                           1
# 8                10083420  00002324090  90                           1
# 9                10000095  65649050130  28.4                         1
# 10               10000096  00193658621  100                          1
#
#     AWP Price  Acquisition Price  Retail Price  WAC Price Contract Flag  \
# 0       17928               9425             0      14342             C
# 1      164760             137300             0     137300             N
# 2       11751               5038             0       8814             C
# 3       40038                831             0        900             N
# 5      763841             587712             0     636534             N
# 6      164698             130386             0     137248             N
# 7      164698             130386             0     137248             N
# 8      100980              77696             0      84150             N
# 9       73516              56565             0      61263             N
# 10       1195               1096          1644        996             N
#
#                   Generic Name                 Form                     Name  \
# 0      hydrocortisone butyrate               TOPICA  HYDROCORTISONE BUTYRATE
# 1                dexamethasone     INTRAOCULR IMPLA              OZURDEX IMP
# 2   amoxicillin/potassium clav                  ORA       AMOXICILLIN-CLAV K
# 3                  anastrozole     ORAL TABLET 1 MG              ANASTROZOLE
# 5               isosulfan blue      SUBCUT VIAL 1 %           ISOSULFAN BLUE
# 6                    entecavir   ORAL TABLET 0.5 MG                BARACLUDE
# 7                    entecavir     ORAL TABLET 1 MG                BARACLUDE
# 8                   duloxetine  HCl ORAL CAPSULE DR                 CYMBALTA
# 9               hydrocortisone      TOPICAL CREAM (               PROCTOCORT
# 10                     lancets         MISCELL EACH    MICROLET LANCET COLOR
#
#                Size
# 0            0.1% O
# 1              1 DS
# 2       400-57 MG C
# 3       1 MG TAB 30
# 5     1% SDV 6X5 ML
# 6     0.5 MG TAB 30
# 7       1 MG TAB 30
# 8   30 MG DR CAP 90
# 9   1 % CRM 28.4 GM
# 10            100CT

# %% [markdown]
# ## Package Analysis

# %%
size = []
forms = []

forms.append(inputData['Form'][:])

# remove duplicates from forms
forms = list(dict.fromkeys([item for sublist in forms for item in sublist]))
print(forms)

print(f"size of og forms: {len(forms)}")
# only keep letters and no other characters in form
# formLettersOnly = [i for i in forms if i.isalpha()]

forms = sorted(list(forms), key=lambda s: s.lower())
for i, form in enumerate(forms):
    print(form)
    if any(char.isdigit() for char in form):
        # print("Removing number: ",form[i])
        forms[i] = ''.join([char for char in form if not char.isdigit()])
        # remove all '(', ')', '.' characters from the forms. Make the code optimal
        
        
forms = set(forms)
# order alphabetically
forms = sorted(list(forms), key=lambda s: s.lower())

print("------------------")
print("------------------")
print("------------------")
print("------------------")
print("------------------")
print("------------------")

for drug_form in forms:
    for i, drugSize in enumerate(inputData):
        if drug_form in inputData['Size'][i]:
            size.append((drug_form, inputData[drugSize][i]))
# Out:
# ['TOPICA', 'INTRAOCULR IMPLA', 'ORA', 'ORAL TABLET 1 MG', 'SUBCUT VIAL 1 %', 'ORAL TABLET 0.5 MG', 'HCl ORAL CAPSULE DR', 'TOPICAL CREAM (', 'MISCELL EACH', 'ORAL', 'NaCl', 'OPHTHALMIC DRO', 'INTRAVEN VI', 'HCl ORAL SOLUTION 10', 'HCl ORAL SOLUTION 5', 'ORAL TABLET 300 MG', 'OPHTHALMIC DROPS 0.3', '', 'ORAL TABLET 4 MG', 'INHALATION V', 'HCl ORAL TABLET 2 M', 'HCl ORAL TABLET 23 M', 'HCl ORAL TABLET 4 M', 'TOP', 'HCl ORAL TABLET 1', 'HCl ORAL TABLET 2.', 'B cplx/C/selen/zinc', 'ORAL TABLET 80 MG', 'ORAL SYRUP', 'TOPICAL LO', 'BUCCAL GUM', 'HCl ORAL CAPSULE 20', 'MISCELL POWDER', 'ORAL TABLET 40 MG', 'MUCOUS MEM SPRAY 35 %', 'ORAL SOLUTION 1 MG', 'INTRAVEN VIAL 10 M', 'NASAL SPRAY 0.', 'ORAL TABLET 50 MG', 'HCl ORAL TABLET 25', 'HCl ORAL TABLET 50', 'HCl ORAL TABLET 100', 'MISCELL SO', 'PF INJECTION', 'OR', 'TOPICAL SOLU', 'SUBCUT PEN INJCTR', 'INTRAVEN VIAL 100M', 'INTRAVEN VIAL 50 M', 'HCl ORAL TABLET 5 MG', 'ORAL POWD', 'ORAL CAPSULE 100 M', 'INTRAMU', 'HCl ORAL TABLET 10', 'TOPICAL CRE', 'LR-D5 IN', 'HCl INTRAVEN CARTRID', 'ORAL ORAL CONC 2 MG/', 'TOPICAL FOAM 35 %', 'ORAL TABLET', 'I', 'HCl NASAL MIST 0', 'ORAL TABLET 20 MG', 'ORAL TABLET 500 MG', 'ORAL CAPSULE 0.5 MG', 'ORAL CAPSULE 1 MG', 'ORAL CAPSULE 5 MG', 'HCl ORAL TAB ER 24', 'HCl ORAL TAB SR 12H', 'ORAL TABLET 5 MG', 'ORAL TABLET 10 MG', 'O', 'ORAL TAB ER 12H 12', 'INJECTION AMPUL 250 MC', 'TOPICAL', 'HCl ORAL CAP ER DEG', 'HBr ORAL SOLUTION', 'INTRAVEN VIAL 80 M', 'INTRAVEN VIAL 200M', 'INTRAVEN VIAL 400M', 'D5W INTR', 'HCl ORAL CAPSULE 10', 'INTRAVEN VIAL', 'INTRAVE', 'INTRAVEN', 'TRANSDERM PATCH TD2', 'ORAL TABLET 2.5 MG', 'INJECTION VI', 'C/Vit B12/FA', 'HCl ORAL TABLET', 'TOPICAL LOTION', 'HCl ORAL SOLUTI', 'ORAL TAB CHEW 50', 'INHALATION H', 'ORAL TABLET 25', 'HCl ORAL TABLET 200', 'HCl/PF INJECTION VIA', 'TOPICAL OINT. (G) 2', 'HCl ORAL TABLET 10 M', 'A virus vaccine/PF I', 'C/folic acd/mv cmb11/calc', 'O.U. TOPICAL SPRA', 'TOPICAL GEL (', 'TOPICAL GEL (GR', 'HCl ORAL TAB ER 24H', 'HCl ORAL TABLE', 'ORAL CAPSULE ER 7', 'HCl ORAL ORAL SUS', 'ORAL CA', 'HCl ORAL TABLET 6', 'ORAL TABLET 2 MG', 'TOPICAL GEL', 'ORAL TABLE', 'MISCE', 'IX human recombinant IN', 'HCl/naloxone HCl O', 'MISCELL DI', 'ORAL TABLET DR 5 MG', 'INJECTION VIAL 1', 'HCl OPHTHALMIC D', 'TOPICAL PASTE (ML) 100 %', 'TOPICAL OINT.', 'TRANSDERM PATCH TDWK', 'ORAL TAB', 'D3 O', 'HCl ORAL TAB RAPDIS', 'ORAL T', 'HCl ORAL CAPSU', 'TO', 'INTRAVEN IV SOLN 20 %', 'MISC', 'T', 'TOPICAL SHAMPOO 1 %', 'ORAL SU', 'TOPICAL SHAMPOO', 'ORAL TABLET 200 MG', 'INTRAVEN V', 'MUCOUS MEM TROCHE', 'HCl ORAL TAB CHEW 5', 'TOPICAL CREAM (G) 1', 'HCl ORAL TAB CHEW 1', 'HCl ORAL CP', 'ORAL TABLET 10', 'Bcomp,C/Zn/vit D3', 'INTRAVEN VIAL 100 M', 'HCl ORAL TABLET 7.', 'INHALATI', 'ORAL TABLET 200', 'D5-0.2%NaCl', 'D5-0.45NaCl', 'NaCl IN', 'ORAL TABLET 1', 'ORAL C', 'D5W INT', 'HCl ORAL TAB ER', 'ORAL TABLET 2.', 'A INTRAMUSC', 'ORAL TABLET 2', 'SUBCUT SYRINGE 90', 'HCl INJECTION VIA', 'ORAL CPMP 12HR 2', 'PF INTR', 'SUBCUT SYRINGE 45M', 'ORAL CPMP 12HR 3', 'ORAL TABLET 70 MG', 'ORAL CAPSULE 0.25 M', 'ORAL CAPSULE 0.5 MC', 'ORAL CAPSULE 300 MG', 'ORAL CAPSULE', 'NS/PF I', 'ORAL TABLET 3', 'ORAL TABLET 4', 'ORAL TABLET 5', 'ORAL ORAL SUSP 200 M', 'ORAL TABLET 6', 'ORAL TABLET 7.', 'HCl INHALATION VI', 'K1) ORAL TAB', 'HCl/dextrose 5 %/PF', 'MISCELL EACH 25', 'INTRAVEN I', 'IN', 'HCl/naloxone HCl', 'MUCOUS MEM LOZENGE 2.8', 'ORAL TABLET 32', 'ORAL TABLET 40', 'INTRAVEN VIA', 'V potassium ORAL SO', 'TOPICAL JEL', 'M', 'INJECTION VIAL 1 G', 'INJECTION VIAL 2 G', 'HCl INJECTION VIAL 2', 'ORAL CAPSULE 15 M', 'ORAL CAPSULE 25 M', 'HCl INTRAVEN VIAL 5', 'TOPICAL CR', 'INTRAMUSC V', 'ORAL ORAL SUSP 100000', 'ORAL CAPSUL', 'OPHTHALMIC DROPS 0', 'A INJECTION V', 'B/pramoxine', 'ORAL SUSP RECON', 'HCl ORA', 'ORAL TINCTURE 1', 'ORAL TAB MPH', 'MISCELL PLAST.', 'ORAL TABLET 60 MG', 'ORAL TABLET 120 MG', 'ORAL CAPSULE 100 MG', 'ORAL CAPSULE 200 MG', 'SUBCUT VIA', 'INJECTION V', 'R', 'INJECTION VIA', 'TOPICAL GEL (G', 'HCl NASAL SPRAY/PUM ...
# size of og forms: 2541
#
# A and B vaccine/PF I
# A and D TOPICAL OINT.
# A and D/white pet/lanolin
# A INJECTION V
# A INTRAMUSC
# A INTRAMUSC V
# A microsphr
# A ORAL CAPSULE 2400 MC
# A ORAL CAPSULE 3000 MC
# A palmitate INTRAMUSC
# A palmitate ORAL CAPSU
# A palmitate/vit C/vit D3 O
# A sod/hyaluronate
# A sodium M
# A solution INTRAVE
# A virus vaccine/PF I
# A,C,D3 no.21/fluoride
# A,C,D3 no.38/fluoride
# A,C,E/aloe
# A,C,E/lutein/minerals ORA
# A,C,Y,W-135 dip/PF
# A,C,Y,W135,c-tet/PF
# A/D3
# A/D3/tocophersolan/vit K O
# A/vit C/biotin/zinc/copper
# A/vit C/D3/zinc/herbal 331
# A/vit C/vit E/selenium yst
# A/vit C/vit E/zinc/copper
# A/vit D3/vit E/vit K1/zinc
# AA/ging/milk
# ASA/caffein
# B
# B comp C no.24/iron/folic
# B comp no.3/folic/C/biotin
# B comp with C/calcium carb
# B comp/folic
# B complex 100 combo no.2 O
# B complex and C
# B complex ORAL CAPSULE
# B complex ORAL TABLET
# B complex/folic acid O
# B complex/zinc/manganese O
# B cplx/C/selen/zinc
# B immun glob/maltose
# B immune globulin IN
# B INJECTION VIAL
# B INTRAMUSC
# B lipid complex I
# B liposome INTRAV
# B MISCELL POWDER
# B sulf
# B sulf/trimethoprim
# B sulfate
# B sulfate INJECTION
# B sulfate,micronized
# B TO
# B vaccine,4-comp
# B vaccine/CpG1018/PF
# B vaccine/dp(a)t-polio/PF
# B virus vac S,M,L/PF
# B virus vaccine/PF I
# B,C no.12/suc
# B,C18/L.casei
# B-12)
# B. subtilis/lutein
# B.anim
# B.coagulan/C/calcium
# B/dexametha
# B/gramicidin
# B/hydrocort
# B/min/saw palmetto/Pygeum
# B/pol/Hib/PF
# B/pramoxine
# B1)
# B1,B2,B3,B5,and B6 IN
# B12/algal oil
# B12/FA/B6/phytost
# B12/folic acid
# B12/levomefol
# B12/levomefolate/vit B6/B2
# B2)
# B2) MISCEL
# B2) ORAL T
# B2/niacin/B6/B12/dexpanth
# B3/copp/Zn/sel/chrom
# B3/pump cart SU
# B5) TOPI
# B6
# B6 OR
# B6/B12/algal oil
# B6/me-thfolate/me-B12/ALA
# Bcomp,C
# Bcomp,C no.9
# Bcomp,C/Cu/zinc
# Bcomp,C/min
# Bcomp,C/Zn
# Bcomp,C/Zn/vit D3
# Br
# Br/olodaterol HCl I
# BT
# BT lispro
# BT,aspart
# BT/cntr
# BUCCAL GUM
# BUCCAL LOZ
# C OR
# C/ascorb sod/multivit-min
# C/B12-if/folic
# C/B12/calciu/stomach conc
# C/B12/FA/Ca/suc
# C/B12/FA/calcium
# C/B12/folic/Ca/suc
# C/B3
# C/B6/B12/zinc
# C/Bacill coag O
# C/D3/zinc/elderberry
# C/E/cuperic/zinc/lutein OR
# C/E/zinc
# C/E/zinc/lutein/zeaxanthin
# C/E/Zn/coppr/lutein/zeaxan
# C/Echinacea purpurea xt OR
# C/elderber/herb 124
# C/FA/B12
# C/FA6/B12/Zn/sa/sto
# C/folate 6/B12/Zn/stomach
# C/folate/B12/zinc/succin
# C/folic ac
# C/folic acd/mv cmb11/calc
# C/glut/lysine/hb124
# C/glut/lysine/hc124
# C/glutamin/lysin/herb124
# C/L.casei
# C/mang
# C/Mang
# C/mang/bosw
# C/manganese
# C/mannose/FOS/bromeln
# C/niacin O
# C/quercetin/bioflav,citrus
# C/succinic acid
# C/Vit B12/FA
# C/vit B12/folic
# C/zinc citrate/elderberry
# C12-18
# Ca
# Ca carb/mag hydrox
# Ca/B6 phos
# CaHMB/collag/mv-min
# CBD) ORAL SOLUTIO
# CF borate
# Cissus qua
# Cl
# Cl TOPICA
# Cl,iso/PF
# Cl/KCl
# Clostridium hist.
# Crotalidae (equine)
# D-galactosidase ORAL TAB
# D.farinae-D.pteronyssinus
# D10W INTRAVE
# D10W/electrolytes
# D14W INTRAVE
# D14W/electrolytes
# D2) OR
# D3
# D3 O
# D3 ORA
# D3) M
# D3) O
# D3)/vit K2
# D3/ALA/lut
# D3/boswellia serra
# D3/hyal/cal bor
# D3/K
# D3/lycop
# D3/mag11/zinc/cop/mang/bor
# D3/magnesium/zinc
# D3/om-3/dha/epa
# D3/vit K
# D3/vit K1
# D3/vitamin K2 (MK4) OR
# D3/zinc/copper/mangan
# D3/Zn/K OR
# D5-0.2%NaCl
# D5-0.45NaCl
# D5-0.9%NaCl
# D5W
# D5W INT
# D5W INTR
# D5W INTRAVEN
# D5W/lytes
# DENTA
# DENTAL
# DENTAL CREAM
# DENTAL GEL (
# DENTAL PASTE
# DENTAL POWDER
# DENTAL SOLUT
# DENTAL TABLET
# DENTAL TOOTHP
# DENTAL TOOTHPASTE
# DF
# DHEA) ORAL CAPSULE
# DHEA) ORAL TABLET
# DHEA) VAGINAL INSE
# DHEA), micronized
# DHEA)/calcium carb
# Dip crm/PF
# DM
# DM OR
# DM/acetam
# DM/acetaminop/GG
# DM/guaifen/acetamin
# E
# E (dl,tocopheryl acet)
# E ac
# E acet./safflower oil
# E acetate T
# E acid succinate MISCE
# E mixed/tocotrienol OR
# E ORAL CAPSULE 268 MG
# E TOPICAL OIL
# E TPGS ORA
# E TPGS)
# E,A,D
# E/AS01B/PF I
# E/biotin
# E/lidocaine/aloe/collagen
# Erwinia-rywn INTR
# FA
# FA 1/dha
# FA no6/dha
# FA OR
# FA ORA
# FA/dha
# FA/dha/epa/FAD/NADH/mv47
# FA/K1/lycop
# FA/lutein/zeaxant
# FA/lycopen/lutein
# FA/lycopene
# FA/o3/dha/epa/fish
# FA/vit K/lutein/zeaxant
# Fab(ovin)
# FOS
# FOS OR
# FOS/fiber O
# FOS/in
# FOS/inulin
# FVIII rec,Fc fusion
# FVIII,B-dom truncat
# FVIII,B-domain del
# FVIII,full length
# FVIII,full length peg
# FVIII,HEK B-delete
# FVIII,sin-chn,B-dm tru
# G (IgG)/glycine
# G (IgG)/sorb/IgA 0-50
# G benz/pen G procaine INTR
# G benzathine INTRAM
# G pot/dextrose-water INTRA
# G potassium INJECTI
# G sodium INJECTION
# G(IgG)-ifas/glycine
# G(IgG)/gly/IgA ov50
# G(IgG)/malt/IgA ov50
# G(IgG)/pro/IgA 0-50
# G-F 20 INTRAARTIC SYRING
# G/gly/gluc/IgA 0-50
# G/gly/IgA avg 46
# HBr MISCELL P
# HBr ORAL CAP24H PE
# HBr ORAL CAPS
# HBr ORAL LIQU
# HBr ORAL SOLUTION
# HBr ORAL TAB ER 24H
# HBr ORAL TABLET 12
# HBr ORAL TABLET 4
# HBr ORAL TABLET 8
# HBr/bupropion
# Hbr/quinidine
# HCl
# HCl (B6)
# HCl (vitamin B6) IN
# HCl (vitamin B6) MI
# HCl (vitamin B6) OR
# HCl BUCCAL FILM
# HCl IMPLANT IMPLAN
# HCl in 0.9 % NaCl/PF
# HCl in 5 % dextrose
# HCl in dextrose 5 %
# HCl in dextrose 5 % I
# HCl in dextrose/PF
# HCl in sterile water I
# HCl INHALATION
# HCl INHALATION MIST
# HCl INHALATION VI
# HCl INJECTION
# HCl INJECTION A
# HCl INJECTION AM
# HCl INJECTION AMP
# HCl INJECTION AMPUL
# HCl INJECTION CA
# HCl INJECTION CARTRID
# HCl INJECTION S
# HCl INJECTION SY
# HCl INJECTION SYRINGE
# HCl INJECTION V
# HCl INJECTION VI
# HCl INJECTION VIA
# HCl INJECTION VIAL
# HCl INJECTION VIAL 0.
# HCl INJECTION VIAL 1
# HCl INJECTION VIAL 10
# HCl INJECTION VIAL 2
# HCl INJECTION VIAL 5
# HCl INJECTION VIAL 50
# HCl INTR
# HCl INTRAMUS
# HCl INTRAMUSC AMPU
# HCl INTRAMUSC VIAL
# HCl INTRAVEN AMP
# HCl INTRAVEN AMPUL 2
# HCl INTRAVEN CARTRID
# HCl INTRAVEN IV SOLN
# HCl INTRAVEN SYRI
# HCl INTRAVEN SYRING
# HCl INTRAVEN SYRINGE
# HCl INTRAVEN V
# HCl INTRAVEN VIA
# HCl INTRAVEN VIAL
# HCl INTRAVEN VIAL 1
# HCl INTRAVEN VIAL 100M
# HCl INTRAVEN VIAL 150M
# HCl INTRAVEN VIAL 2
# HCl INTRAVEN VIAL 2.
# HCl INTRAVEN VIAL 20
# HCl INTRAVEN VIAL 200
# HCl INTRAVEN VIAL 3
# HCl INTRAVEN VIAL 4
# HCl INTRAVEN VIAL 400
# HCl INTRAVEN VIAL 5
# HCl INTRAVEN VIAL 50
# HCl INTRAVEN VIAL 7
# HCl/epinephrine INJE
# HCl/epinephrine/PF
# HCl/epinephrine/PF I
# HCl/fluocinolone
# HCl/fluorescein sod
# HCl/glimepiride O
# HCl/glycerin OPHTH
# HCl/hard fat REC
# HCl/menthol MUCOUS M
# HCl/menthol TOPICAL
# HCl/metformin HCl
# HCl/mometasone NAS
# HCl/naloxone HCl
# HCl/naloxone HCl O
# HCl/PF EPIDURAL VIAL
# HCl/PF INJECTIO
# HCl/PF INJECTION
# HCl/PF INJECTION A
# HCl/PF INJECTION AMP
# HCl/PF INJECTION CA
# HCl/PF INJECTION I
# HCl/PF INJECTION P
# HCl/PF INJECTION S
# HCl/PF INJECTION SY
# HCl/PF INJECTION SYR
# HCl/PF INJECTION V
# HCl/PF INJECTION VI
# HCl/PF INJECTION VIA
# HCl/PF INTRATHE
# HCl/PF INTRAVEN SYRI
# HCl/PF INTRAVEN VI
# HCl/PF INTRAVEN VIAL
# HCl/PF OPHTHALM
# HCl/PF OPHTHALMIC D
# HCl/PF OPHTHALMIC GE
# HCl/pheniramine OP
# HCl/prometh HCl
# HCl/pseudoephedrine
# HCl/simethicone ORA
# HCl/timolol maleat
# HCl/triprolidine
# HCl/zinc acet
# HCl/zinc acetate TOP
# HCl/zinc sulf
# Hib/PF
# I
# IG,antithymocyt,equ
# Ig/maltose IN
# IgG)klhw
# II acetate, human
# II TOPICAL CLE
# II TOPICAL CRE
# II TOPICAL LOT
# II/B3/hyalur ac
# II/niacinamide
# II/salicylic/B3
# III (plasma der)
# IMPLANT
# IMPLANT KIT
# IMPLANT PELLET(EA
# IMPLANT VIAL 10MG/
# IN
# INHALA
# INHALAT
# INHALATI
# INHALATIO
# INHALATION
# INHALATION A
# INHALATION AER POW
# INHALATION AMP
# INHALATION AMPUL-NE
# INHALATION BLST W/DE
# INHALATION CAP W/DE
# INHALATION CAP W/DEV
# INHALATION CARTRIDGE
# INHALATION H
# INHALATION HFA AER
# INHALATION LIQUID
# INHALATION LIQUID 1
# INHALATION LIQUID 9
# INHALATION SOLUTI
# INHALATION V
# INHALATION VIAL
# INHALATION VIAL 25 M
# INHALATION VIAL 35M
# INHALATION VIAL-NE
# INHALATION VIAL-NEB
# INJ
# INJEC
# INJECT
# INJECTI
# INJECTIO
# INJECTION
# INJECTION A
# INJECTION AMPUL 100 MC
# INJECTION AMPUL 250 MC
# INJECTION AMPUL 50
# INJECTION AUTO INJ
# INJECTION CARTRIDGE
# INJECTION CARTRIDGE 5
# INJECTION KI
# INJECTION KIT
# INJECTION KIT 1 MG
# INJECTION S
# INJECTION SY
# INJECTION SYR
# INJECTION SYRI
# INJECTION SYRINGE
# INJECTION SYRINGE 3
# INJECTION SYRINGE 4
# INJECTION SYRINGE 5 M
# INJECTION V
# INJECTION VI
# INJECTION VIA
# INJECTION VIAL
# INJECTION VIAL 0.2
# INJECTION VIAL 0.25
# INJECTION VIAL 1
# INJECTION VIAL 1 G
# INJECTION VIAL 1 M
# INJECTION VIAL 1 MG
# INJECTION VIAL 10
# INJECTION VIAL 10 M
# INJECTION VIAL 10 UNI
# INJECTION VIAL 100
# INJECTION VIAL 100 M
# INJECTION VIAL 100 MG
# INJECTION VIAL 15 MG
# INJECTION VIAL 2
# INJECTION VIAL 2 G
# INJECTION VIAL 2 MG
# INJECTION VIAL 2 MG/
# INJECTION VIAL 2.5
# INJECTION VIAL 20
# INJECTION VIAL 20 M
# INJECTION VIAL 25
# INJECTION VIAL 3.5
# INJECTION VIAL 30
# INJECTION VIAL 300
# INJECTION VIAL 300 M
# INJECTION VIAL 4 MG/
# INJECTION VIAL 40
# INJECTION VIAL 480M
# INJECTION VIAL 5
# INJECTION VIAL 5 MCG
# INJECTION VIAL 5 MG
# INJECTION VIAL 5 MG/M
# INJECTION VIAL 500MCG/
# INJECTION VIAL 6 G
# INJECTION VIAL 660
# INT
# INTR
# INTRA
# INTRAA
# INTRAARTER AMPUL
# INTRAARTIC
# INTRACAVER KIT 10
# INTRACAVER KIT 20
# INTRACAVER KIT 40
# INTRACAVER VIAL 20
# INTRACAVER VIAL 40
# INTRADERM
# INTRAM
# INTRAMU
# INTRAMUS
# INTRAMUSC
# INTRAMUSC K
# INTRAMUSC P
# INTRAMUSC S
# INTRAMUSC SUSER S
# INTRAMUSC SUSER V
# INTRAMUSC SYRI
# INTRAMUSC SYRINGE
# INTRAMUSC V
# INTRAMUSC VIA
# INTRAMUSC VIAL 10 M
# INTRAMUSC VIAL 100
# INTRAMUSC VIAL 50
# INTRAMUSC VIAL 50M
# INTRAO
# INTRAOC
# INTRAOCULR
# INTRAOCULR IMPLA
# INTRAOCULR IMPLANT
# INTRAOCULR S
# INTRAOCULR SYRING
# INTRAOCULR SYRINGE
# INTRAOCULR VI
# INTRAOCULR VIAL
# INTRAOCULR VIAL 0.01
# INTRAOCULR VIAL 2M
# INTRAOCULR VIAL 8M
# INTRATHEC SYRINGE 100
# INTRATHEC SYRINGE 20K
# INTRATHEC SYRINGE 400
# INTRATHEC SYRINGE 50
# INTRATHEC V
# INTRATHEC VIAL 10000/
# INTRATHEC VIAL 180 MG/
# INTRATHEC VIAL 200 M
# INTRATHEC VIAL 20K MC
# INTRATHEC VIAL 300 M
# INTRATHEC VIAL 40000/
# INTRAUTERI IUD
# INTRAV
# INTRAVE
# INTRAVEN
# INTRAVEN AMPUL
# INTRAVEN AMPUL 25
# INTRAVEN AMPUL 5 MG
# INTRAVEN CART
# INTRAVEN EMULSIO
# INTRAVEN I
# INTRAVEN INFU
# INTRAVEN INFUS. BT
# INTRAVEN INFUS. BTL
# INTRAVEN INFUS. BTL 14
# INTRAVEN INFUS. BTL 24
# INTRAVEN INFUS. BTL 30
# INTRAVEN INFUS. BTL 35
# INTRAVEN IV
# INTRAVEN IV S
# INTRAVEN IV SO
# INTRAVEN IV SOLN
# INTRAVEN IV SOLN 20 %
# INTRAVEN KIT 35 M
# INTRAVEN PIGGYBA
# INTRAVEN PIGGYBACK 3
# INTRAVEN PIGGYBACK 8
# INTRAVEN PLAS
# INTRAVEN PLAST. B
# INTRAVEN PLAST. BA
# INTRAVEN SY
# MISCELL WAX
# MISCELL WAX 100 %
# MU
# MUCOU
# MUCOUS
# MUCOUS ME
# MUCOUS MEM
# MUCOUS MEM CREAM (G
# MUCOUS MEM GEL
# MUCOUS MEM GEL (GRA
# MUCOUS MEM LIQUID 2
# MUCOUS MEM LOZ
# MUCOUS MEM LOZENGE 1.1
# MUCOUS MEM LOZENGE 2.8
# MUCOUS MEM LOZENGE 4.8
# MUCOUS MEM LOZENGE 5.4
# MUCOUS MEM LOZENGE 5.8
# MUCOUS MEM LOZENGE 7.5
# MUCOUS MEM LOZENGE 7.6
# MUCOUS MEM MA BUC TAB
# MUCOUS MEM S
# MUCOUS MEM SPR
# MUCOUS MEM SPRAY 1.4 %
# MUCOUS MEM SPRAY 20
# MUCOUS MEM SPRAY 35 %
# MUCOUS MEM TROCHE
# NA
# Na) I
# NaCl
# NaCl (iso-os)
# NaCl I
# NaCl IN
# NaCl INT
# NaCl INTRA
# NaCl, iso-osm
# NaCl, iso-osm I
# NaCl, iso-osm IN
# NaCl,iso-os
# NaCL,iso-osm IN
# NaCl,iso-osm/PF
# NaCl,iso-osmot/PF
# NaCl/KCl/asb/C
# NaCl/pot
# NaCl/water
# NaHCO3/KCl/peg
# NAS
# NASA
# NASAL
# NASAL A
# NASAL AE
# NASAL DROPS 0.
# NASAL GEL MD PMP
# NASAL HFA AER AD 3
# NASAL IMPLA
# NASAL INHALER
# NASAL NAS SP
# NASAL S
# NASAL SP
# NASAL SPR
# NASAL SPRA
# NASAL SPRAY
# NASAL SPRAY 0.
# NASAL SPRAY 10 MG
# NASAL SPRAY 10 MG/ML
# NASAL SPRAY 10MG/SPRA
# NASAL SPRAY 15/2 SPRA
# NASAL SPRAY 2.
# NASAL SPRAY 2.5 M
# NASAL SPRAY 20 MG
# NASAL SPRAY 20/2 SPRA
# NASAL SPRAY 25 MCG
# NASAL SPRAY 3 MG
# NASAL SPRAY 5 MG
# NASAL SPRAY 5 MG/SPR
# NASAL SPRAY 5 MG/SPRA
# NASAL SPRAY/PU
# NASAL SPRAY/PUMP 32
# NASAL SPRAY/PUMP 5
# NPH hum/reg insulin hm
# NPH human isophane SUB
# NS/PF I
# O
# O.U. DENTA
# O.U. TOPICAL SPRA
# OPH
# OPHT
# OPHTH
# OPHTHA
# OPHTHAL
# OPHTHALM
# OPHTHALMI
# OPHTHALMIC
# OPHTHALMIC D
# OPHTHALMIC DR
# OPHTHALMIC DRO
# OPHTHALMIC DROPER
# OPHTHALMIC DROPERE
# OPHTHALMIC DROPS
# OPHTHALMIC DROPS 0
# OPHTHALMIC DROPS 0.
# OPHTHALMIC DROPS 0.25
# OPHTHALMIC DROPS 0.3
# OPHTHALMIC DROPS 0.5
# OPHTHALMIC DROPS 0.5 %
# OPHTHALMIC DROPS 1
# OPHTHALMIC DROPS 1.25
# OPHTHALMIC DROPS SUS
# OPHTHALMIC EACH 25X50M
# OPHTHALMIC GEL (G
# OPHTHALMIC GEL (GR
# OPHTHALMIC INSER
# OPHTHALMIC O
# OPHTHALMIC OIN
# S (ph 7.4) INTRAVE
# S solution INTRAVE
# SF no.18
# SF no.20
# SF no.24
# Siberian fir
# SU
# SUB
# SUBC
# SUBCU
# SUBCUT
# SUBCUT AUTO
# SUBCUT AUTO I
# SUBCUT AUTO IN
# SUBCUT AUTO INJC
# SUBCUT AUTO INJCT
# SUBCUT AUTO INJCT 0.5
# SUBCUT AUTO INJCT 1
# SUBCUT AUTO INJCT 1 M
# SUBCUT AUTO INJCT 12
# SUBCUT AUTO INJCT 20
# SUBCUT AUTO INJCT 8
# SUBCUT AUTOINJ
# SUBCUT C
# SUBCUT CARTRIDG
# SUBCUT CARTRIDGE 10
# SUBCUT CARTRIDGE 12
# SUBCUT CARTRIDGE 5
# SUBCUT CARTRIDGE 50
# SUBCUT I
# SUBCUT IMPLA
# SUBCUT INS
# SUBCUT INS PEN
# SUBCUT INSUL
# SUBCUT INSULN
# SUBCUT INSULN P
# SUBCUT KIT
# SUBCUT KIT 5 MG
# SUBCUT LIQ ER SYR
# SUBCUT P
# SUBCUT PEN
# SUBCUT PEN I
# SUBCUT PEN IJ
# SUBCUT PEN IJ KIT 4
# SUBCUT PEN IJ KIT 8
# SUBCUT PEN IN
# SUBCUT PEN INJ
# SUBCUT PEN INJCTR
# SUBCUT PEN INJCTR 1
# SUBCUT PEN INJCTR 10
# SUBCUT PEN INJCTR 15
# SUBCUT PEN INJCTR 2
# SUBCUT PEN INJCTR 20
# SUBCUT PEN INJCTR 3
# SUBCUT PEN INJCTR 30
# SUBCUT PEN INJCTR 5
# SUBCUT PEN INJCTR 50
# SUBCUT PEN INJCTR 5M
# SUBCUT PEN INJCTR 7
# SUBCUT S
# SUBCUT SUSER SYR 1
# SUBCUT SUSER SYR 2
# SUBCUT SUSER SYR 5
# SUBCUT SUSER SYR 7
# SUBCUT SUSER SYR 9
# SUBCUT SYR
# SUBCUT SYR W/ IN
# SUBCUT SYRI
# SUBCUT SYRIN
# SUBCUT SYRING
# SUBCUT SYRINGE
# SUBCUT SYRINGE 0.2M
# SUBCUT SYRINGE 0.4M
# SUBCUT SYRINGE 0.6M
# SUBCUT SYRINGE 0.8M
# SUBCUT SYRINGE 1 MG/0
# SUBCUT SYRINGE 1.2M
# SUBCUT SYRINGE 1.4M
# SUBCUT SYRINGE 1.6M
# SUBCUT SYRINGE 1.8M
# SUBCUT SYRINGE 100
# SUBCUT SYRINGE 100 M
# SUBCUT SYRINGE 100MG
# SUBCUT SYRINGE 100MG/
# SUBCUT SYRINGE 125 M
# SUBCUT SYRINGE 140
# SUBCUT SYRINGE 150
# SUBCUT SYRINGE 150MG
# SUBCUT SYRINGE 162
# SUBCUT SYRINGE 1MG/
# SUBCUT SYRINGE 200 M
# SUBCUT SYRINGE 200MG
# SUBCUT SYRINGE 25MG
# SUBCUT SYRINGE 2MG/
# SUBCUT SYRINGE 30
# SUBCUT SYRINGE 300 M
# SUBCUT SYRINGE 40M
# SUBCUT SYRINGE 45M
# SUBCUT SYRINGE 50MG
# SUBCUT SYRINGE 50MG/
# SUBCUT SYRINGE 6
# SUBCUT SYRINGE 60 MG
# SUBCUT SYRINGE 75M
# SUBCUT SYRINGE 75MG
# SUBCUT SYRINGE 80 M
# SUBCUT SYRINGE 87.5M
# SUBCUT SYRINGE 90
# SUBCUT SYRINGEKIT 1
# SUBCUT SYRINGEKIT 2
# SUBCUT SYRINGEKIT 4
# SUBCUT SYRINGEKIT 8
# SUBCUT V
# SUBCUT VI
# SUBCUT VIA
# SUBCUT VIAL
# SUBCUT VIAL 0.4 MG
# SUBCUT VIAL 0.56 MG
# SUBCUT VIAL 1
# SUBCUT VIAL 1 %
# SUBCUT VIAL 1 MG/0.2M
# SUBCUT VIAL 1.2 MG
# SUBCUT VIAL 10
# SUBCUT VIAL 10 MG
# SUBCUT VIAL 100
# SUBCUT VIAL 100 MG
# SUBCUT VIAL 10MG/M
# SUBCUT VIAL 120 MG/1
# SUBCUT VIAL 125 MC
# SUBCUT VIAL 15
# SUBCUT VIAL 150 MG
# SUBCUT VIAL 24MG/1.
# SUBCUT VIAL 25 MG
# SUBCUT VIAL 250 MC
# SUBCUT VIAL 25MG/0.
# SUBCUT VIAL 3
# SUBCUT VIAL 30
# SUBCUT VIAL 30 MG
# SUBCUT VIAL 300
# SUBCUT VIAL 4
# SUBCUT VIAL 45MG/0
# SUBCUT VIAL 480
# SUBCUT VIAL 5 MG
# SUBCUT VIAL 5.8 MG
# SUBCUT VIAL 500 MC
# SUBCUT VIAL 60
# SUBCUT VIAL 75 UNI
# SUBCUT VIAL 90 MG
# SUBCUT WEAR
# SUBCUT WEAR INJCT 4
# SUBL
# SUBLINGUA
# SUBLINGUAL
# SUBLINGUAL T
# SUBLINGUAL TAB RAP
# SUBLINGUAL TAB S
# SUBLINGUAL TAB SUBL
# SUBLINGUAL TAB SUBL 500
# T
# T/lactated ringers
# TDF)
# TO
# TOP
# TOPI
# TOPIC
# TOPICA
# TOPICAL
# TOPICAL ADH.
# TOPICAL ADH. P
# TOPICAL ADH. PA
# TOPICAL ADH. PATCH 0
# TOPICAL ADH. PATCH 1
# TOPICAL ADH. PATCH 4
# TOPICAL ADH. PATCH 5
# TOPICAL ADH. PATCH 5 %
# TOPICAL ADH. PATCH 7.5
# TOPICAL AER
# TOPICAL AERO
# TOPICAL AERO POWD 1
# TOPICAL AEROSOL 20
# TOPICAL B
# TOPICAL BANDA
# TOPICAL BANDAG
# TOPICAL BANDAGE 4"X
# TOPICAL BAR
# TOPICAL C
# TOPICAL CLE
# TOPICAL CLEAN
# TOPICAL CLEANSE
# TOPICAL CR
# TOPICAL CRE
# TOPICAL CREA
# TOPICAL CREAM
# TOPICAL CREAM (
# TOPICAL CREAM (G
# TOPICAL CREAM (G)
# TOPICAL CREAM (G) 0
# TOPICAL CREAM (G) 0.
# TOPICAL CREAM (G) 0.0
# TOPICAL CREAM (G) 1
# TOPICAL CREAM (G) 1.25
# TOPICAL CREAM (G) 10
# TOPICAL CREAM (G) 10 %
# TOPICAL CREAM (G) 100
# TOPICAL CREAM (G) 20 %
# TOPICAL CREAM (G) 3
# TOPICAL CREAM (G) 39 %
# TOPICAL CREAM (G) 4
# TOPICAL CREAM (G) 40 %
# TOPICAL CREAM (G) 41 %
# TOPICAL CREAM (G) 45 %
# TOPICAL CREAM (G) 47 %
# TOPICAL CREAM (G) 5
# TOPICAL CREAM (G) 50 %
# TOPICAL CREAM PACK 3
# TOPICAL CREAM PACK 5
# TOPICAL CREAM(M
# TOPICAL CREAM(ML) 3 %
# TOPICAL CRM MD PMP 2
# TOPICAL CRM MD PMP 3
# TOPICAL CRM/PE
# TOPICAL DROP
# TOPICAL DROP W/APP
# TOPICAL EACH
# TOPICAL EM
# TOPICAL FOAM
# TOPICAL FOAM 0.0
# TOPICAL FOAM 0.05 %
# TOPICAL FOAM 0.1 %
# TOPICAL FOAM 15 %
# TOPICAL FOAM 2 %
# TOPICAL FOAM 35 %
# TOPICAL FOAM 5 %
# TOPICAL FOAM 6
# TOPICAL G
# TOPICAL GEL
# TOPICAL GEL (
# TOPICAL GEL (G
# TOPICAL GEL (GR
# TOPICAL GEL (GRA
# TOPICAL GEL (GRAM
# TOPICAL GEL (GRAM)
# TOPICAL GEL (GRAM) 0
# TOPICAL GEL (GRAM) 0.
# TOPICAL GEL (GRAM) 2 %
# TOPICAL GEL (GRAM) 2.5
# TOPICAL GEL (GRAM) 32 P
# TOPICAL GEL (GRAM) 5 %
# TOPICAL GEL (ML)
# TOPICAL GEL (ML) 4 %
# TOPICAL GEL (ML) 45 %
# TOPICAL GEL ER(ML)
# TOPICAL GEL W/PU
# TOPICAL GEL W/PUMP 0
# TOPICAL GEL W/PUMP 7.5
# TOPICAL JEL
# TOPICAL JELLY
# TOPICAL K
# TOPICAL KT SHM
# TOPICAL L
# TOPICAL LIQ-FIL
# TOPICAL LIQU
# TOPICAL LIQUI
# TOPICAL LIQUID
# TOPICAL LIQUID 1 %
# TOPICAL LIQUID 1.5 %
# TOPICAL LIQUID 16 %
# TOPICAL LO
# TOPICAL LOT
# TOPICAL LOTIO
# TOPICAL LOTION
# TOPICAL LOTION 0
# TOPICAL LOTION 0.04
# TOPICAL LOTION 0.05
# TOPICAL LOTION 0.05 %
# TOPICAL LOTION 0.1 %
# TOPICAL LOTION 0.5
# TOPICAL LOTION 0.5 %
# TOPICAL LOTION 10 %
# TOPICAL LOTION 40 %
# TOPICAL M
# TOPICAL MED. PA
# TOPICAL MED. PAD 5
# TOPICAL MED. SWA
# TOPICAL MED. T
# TOPICAL OIL
# TOPICAL OIL 100 %
# TOPICAL OIN
# TOPICAL OINT
# TOPICAL OINT P
# TOPICAL OINT PACK
# TOPICAL OINT.
# TOPICAL OINT. (
# TOPICAL OINT. (G
# TOPICAL OINT. (G)
# TOPICAL OINT. (G) 0
# TOPICAL OINT. (G) 0.0
# TOPICAL OINT. (G) 1
# TOPICAL OINT. (G) 100
# TOPICAL OINT. (G) 2
# TOPICAL OINT. (G) 2 %
# TOPICAL OINT. (G) 3
# TOPICAL OINT. (G) 4
# TOPICAL OINT. (G) 5
# TOPICAL P
# TOPICAL PACK
# TOPICAL PACKE
# TOPICAL PACKET 500
# TOPICAL PAST
# TOPICAL PASTE (ML) 100 %
# TOPICAL POW
# TOPICAL POWDER
# TOPICAL POWDER 0.15 %
# TOPICAL POWDER 1 %
# TOPICAL POWDER 100000
# TOPICAL S
# TOPICAL SHA
# TOPICAL SHAMP
# TOPICAL SHAMPO
# TOPICAL SHAMPOO
# TOPICAL SHAMPOO 0.5 %
# TOPICAL SHAMPOO 1
# TOPICAL SHAMPOO 1 %
# TOPICAL SHAMPOO 2
# TOPICAL SHAMPOO 2 %
# TOPICAL SO
# TOPICAL SOL
# TOPICAL SOL W/AP
# TOPICAL SOL W/APPL
# TOPICAL SOL-FIL
# TOPICAL SOLN
# TOPICAL SOLU
# TOPICAL SOLUTI
# TOPICAL SOLUTIO
# TOPICAL SOLUTION
# TOPICAL SOLUTION 0
# TOPICAL SOLUTION 0.5
# TOPICAL SOLUTION 2 %
# TOPICAL SOLUTION 20 %
# TOPICAL SOLUTION 5 %
# TOPICAL SOLUTION 8
# TOPICAL SOLUTION 99.5
# TOPICAL SP
# TOPICAL SPIRIT
# TOPICAL SPR
# TOPICAL SPRA
# TOPICAL SPRAY
# TOPICAL SPRAY 0
# TOPICAL SPRAY 1
# TOPICAL SPRAY 1 %
# TOPICAL SPRAY 20 %
# TOPICAL SPRAY 4 %
# TOPICAL SPRAY/PUMP 20
# TOPICAL STRIP 0.
# TOPICAL SUS
# TOPICAL SUSPENSION 0.
# TOPICAL T
# TOPICAL TAPE 1"
# TOPICAL TAPE 2"X
# TOPICAL TIN
# TOPICAL TINCTURE
# TOPICAL VIAL
# TRANS
# TRANSDERM
# TRANSDERM CR
# TRANSDERM CRE
# TRANSDERM GEL (GR
# TRANSDERM GEL MD
# TRANSDERM GEL MD PMP
# TRANSDERM GEL PAC
# TRANSDERM GEL PACKET
# TRANSDERM OINT.
# TRANSDERM PA
# TRANSDERM PATC
# TRANSDERM PATCH
# TRANSDERM PATCH DYSQ
# TRANSDERM PATCH T
# TRANSDERM PATCH TD
# TRANSDERM PATCH TD2
# TRANSDERM PATCH TD24
# TRANSDERM PATCH TD72
# TRANSDERM PATCH TDS
# TRANSDERM PATCH TDSW
# TRANSDERM PATCH TDWK
# TRANSDERM SOL MD
# TRANSDERM SPRAY 1.53
# TRANSLING SPRAY
# U-500,ndl,0.5mL
# URE
# URETHRAL
# URETHRAL SUPP.URET
# V
# V potassium ORAL SO
# V potassium ORAL TA
# VAGIN
# VAGINAL
# VAGINAL C
# VAGINAL CMB
# VAGINAL CRE
# VAGINAL CREAM/APP
# VAGINAL CREAM/APPL
# VAGINAL CREAM/APPL 0
# VAGINAL CRM
# VAGINAL GEL W/AP
# VAGINAL GEL/PF AP
# VAGINAL INSERT 10 MC
# VAGINAL INSERT 4 MCG
# VAGINAL INSERT ER
# VAGINAL INSR DS PK 1
# VAGINAL INSR DS PK 4
# VAGINAL KIT
# VAGINAL OIN/PF APP
# VAGINAL SOLUTI
# VAGINAL SUP
# VAGINAL SUPP.VAG 8
# VAGINAL TABLET 10 MC
# VAGINAL VAG
# VAGINAL VAG RING 7.5
# VI polysacch vaccine I
# VIIa,recomb
# VIIa,recomb-jncw I
# VWF INTR
# Willebrand factor INTRAVEN
# Xa,inactivated-zhzo INT
# XIII A-subunit,recomb I
# XIII INTRAVEN VIAL 1000
# ------------------
# ------------------
# ------------------
# ------------------
# ------------------
# ------------------
#
# A and B vaccine/PF I
# A and D TOPICAL OINT.
# A and D/white pet/lanolin
# A INJECTION V
# A INTRAMUSC
# A INTRAMUSC V
# A microsphr
# A ORAL CAPSULE  MC
# A palmitate INTRAMUSC
# A palmitate ORAL CAPSU
# A palmitate/vit C/vit D O
# ...
# HCl/PF INJECTION AMP
# HCl/PF INJECTION CA
# HCl/PF INJECTION I
# HCl/PF INJECTION P
# HCl/PF INJECTION S
# HCl/PF INJECTION SY
# HCl/PF INJECTION SYR
# HCl/PF INJECTION V
# HCl/PF INJECTION VI
# HCl/PF INJECTION VIA
# HCl/PF INTRATHE
# HCl/PF INTRAVEN SYRI
# HCl/PF INTRAVEN VI
# HCl/PF INTRAVEN VIAL
# HCl/PF OPHTHALM
# HCl/PF OPHTHALMIC D
# HCl/PF OPHTHALMIC GE
# HCl/pheniramine OP
# HCl/prometh HCl
# HCl/pseudoephedrine
# HCl/simethicone ORA
# HCl/timolol maleat
# HCl/triprolidine
# HCl/zinc acet
# HCl/zinc acetate TOP
# HCl/zinc sulf
# Hib/PF
# I
# IG,antithymocyt,equ
# Ig/maltose IN
# IgG)klhw
# II acetate, human
# II TOPICAL CLE
# II TOPICAL CRE
# II TOPICAL LOT
# II/B/hyalur ac
# II/niacinamide
# II/salicylic/B
# III (plasma der)
# IMPLANT
# IMPLANT KIT
# IMPLANT PELLET(EA
# IMPLANT VIAL MG/
# IN
# INHALA
# INHALAT
# INHALATI
# INHALATIO
# INHALATION
# INHALATION A
# INHALATION AER POW
# INHALATION AMP
# INHALATION AMPUL-NE
# INHALATION BLST W/DE
# INHALATION CAP W/DE
# INHALATION CAP W/DEV
# INHALATION CARTRIDGE
# INHALATION H
# INHALATION HFA AER
# INHALATION LIQUID
# INHALATION LIQUID
# INHALATION SOLUTI
# INHALATION V
# INHALATION VIAL
# INHALATION VIAL  M
# INHALATION VIAL M
# INHALATION VIAL-NE
# INHALATION VIAL-NEB
# INJ
# INJEC
# INJECT
# INJECTI
# INJECTIO
# INJECTION
# INJECTION A
# INJECTION AMPUL
# INJECTION AMPUL  MC
# INJECTION AUTO INJ
# INJECTION CARTRIDGE
# INJECTION CARTRIDGE
# INJECTION KI
# INJECTION KIT
# INJECTION KIT  MG
# INJECTION S
# INJECTION SY
# INJECTION SYR
# INJECTION SYRI
# INJECTION SYRINGE
# INJECTION SYRINGE
# INJECTION SYRINGE  M
# INJECTION V
# INJECTION VI
# INJECTION VIA
# INJECTION VIAL
# INJECTION VIAL
# INJECTION VIAL  G
# INJECTION VIAL  M
# INJECTION VIAL  MCG
# INJECTION VIAL  MG
# INJECTION VIAL  MG/
# MUCOUS MEM GEL
# MUCOUS MEM GEL (GRA
# MUCOUS MEM LIQUID
# MUCOUS MEM LOZ
# MUCOUS MEM LOZENGE .
# MUCOUS MEM MA BUC TAB
# MUCOUS MEM S
# MUCOUS MEM SPR
# MUCOUS MEM SPRAY
# MUCOUS MEM SPRAY  %
# MUCOUS MEM SPRAY . %
# MUCOUS MEM TROCHE
# NA
# Na) I
# NaCl
# NaCl (iso-os)
# NaCl I
# NaCl IN
# NaCl INT
# NaCl INTRA
# NaCl, iso-osm
# NaCl, iso-osm I
# NaCl, iso-osm IN
# NaCl,iso-os
# NaCL,iso-osm IN
# NaCl,iso-osm/PF
# NaCl,iso-osmot/PF
# NaCl/KCl/asb/C
# NaCl/pot
# NaCl/water
# NaHCO/KCl/peg
# NAS
# NASA
# NASAL
# NASAL A
# NASAL AE
# NASAL DROPS .
# NASAL GEL MD PMP
# NASAL HFA AER AD
# NASAL IMPLA
# NASAL INHALER
# NASAL NAS SP
# NASAL S
# NASAL SP
# NASAL SPR
# NASAL SPRA
# NASAL SPRAY
# NASAL SPRAY  MCG
# NASAL SPRAY  MG
# NASAL SPRAY  MG/ML
# NASAL SPRAY  MG/SPR
# NASAL SPRAY  MG/SPRA
# NASAL SPRAY .
# NASAL SPRAY . M
# NASAL SPRAY / SPRA
# NASAL SPRAY MG/SPRA
# NASAL SPRAY/PU
# NASAL SPRAY/PUMP
# NPH hum/reg insulin hm
# NPH human isophane SUB
# NS/PF I
# O
# O.U. DENTA
# O.U. TOPICAL SPRA
# OPH
# OPHT
# OPHTH
# OPHTHA
# OPHTHAL
# OPHTHALM
# OPHTHALMI
# OPHTHALMIC
# OPHTHALMIC D
# OPHTHALMIC DR
# OPHTHALMIC DRO
# OPHTHALMIC DROPER
# OPHTHALMIC DROPERE
# OPHTHALMIC DROPS
# OPHTHALMIC DROPS
# OPHTHALMIC DROPS .
# OPHTHALMIC DROPS . %
# OPHTHALMIC DROPS SUS
# OPHTHALMIC EACH XM
# OPHTHALMIC GEL (G
# OPHTHALMIC GEL (GR
# OPHTHALMIC INSER
# OPHTHALMIC O
# OPHTHALMIC OIN
# OPHTHALMIC OINT. (G
# OPHTHALMIC SOL
# OR
# ORA
# ORAL
# ORAL C
# ORAL CA
# ORAL CAP
# ORAL CAP DR
# ORAL CAP DR BP
# ORAL CAP DS PK M
# ORAL CAP E
# ORAL CAP ER
# ORAL CAP ER H
# ORAL CAP ER H  M
# ORAL CAP ER H  MG
# ORAL CAP ER H .
# ORAL CAP ER P
# ORAL CAP LQ RAP
# ORAL CAP S
# ORAL CAP SA H
# ORAL CAP SPR
# ORAL CAP SPRINK
# ORAL CAP(DRTAB)
# ORAL CAPDR - ER  M
# ORAL CAPH PEL
# ORAL CAPS
# ORAL CAPSU
# ORAL CAPSUL
# ORAL CAPSULE
# ORAL CAPSULE
# ORAL CAPSULE  M
# ORAL CAPSULE  MC
# ORAL CAPSULE  MCG
# ORAL CAPSULE  MG
# ORAL CAPSULE (
# ORAL CAPSULE .
# PE/acetaminophen
# PE/DM/acetamin/GG
# PE/DM/acetaminophen/GG
# PEG)
# PER
# PF
# PF I
# PF INJ
# PF INJE
# PF INJECT
# PF INJECTI
# PF INJECTIO
# PF INJECTION
# PF INJECTION SY
# PF INJECTION VI
# PF INJECTION VIAL
# PF INT
# PF INTR
# PF INTRAOCULR VI
# PF INTRAVEN C
# PF INTRAVEN P
# PF INTRAVEN S
# PF INTRAVEN V
# PF INTRAVEN VIAL
# PF O
# PF OP
# PF OPH
# PF OPHT
# PF OPHTHA
# PF OPHTHAL
# PF OPHTHALMIC
# PF OPHTHALMIC DROP
# PF OPHTHALMIC DROPE
# PF SUBC
# PF SUBCUT AUTO IN
# PF SUBCUT SYRINGE
# PF SUBCUT VIAL
# PKU no. O
# R
# R (ph .) INTRAVE
# R solution INTRAVE
# R solution/DW INT
# RE
# REC
# RECTA
# RECTAL
# RECTAL ENEMA
# RECTAL ENEMA
# RECTAL ENEMA  G/
# RECTAL ENEMA MG/
# RECTAL FOAM/APPL
# RECTAL KIT -.-MG
# RECTAL KIT . MG
# RECTAL KIT .--
# RECTAL OINT. (G)
# RECTAL SOL/PF APP .
# RECTAL SUPP.R
# RECTAL SUPP.RECT
# RECTAL SUPP.RECT
# RECTAL SUPP.RECT  M
# RECTAL SUPP.RECT ADUL
# RECTAL SUPP.RECT PEDI
# RF
# S
# S (ph .) INTRAVE
# S solution INTRAVE
# SF no.
# Siberian fir
# SU
# SUB
# SUBC
# SUBCU
# SUBCUT
# SUBCUT AUTO
# SUBCUT AUTO I
# SUBCUT AUTO IN
# SUBCUT AUTO INJC
# SUBCUT AUTO INJCT
# SUBCUT AUTO INJCT
# SUBCUT AUTO INJCT  M
# SUBCUT AUTO INJCT .
# SUBCUT AUTOINJ
# SUBCUT C
# SUBCUT CARTRIDG
# SUBCUT CARTRIDGE
# SUBCUT I
# SUBCUT IMPLA
# SUBCUT INS
# SUBCUT INS PEN
# SUBCUT INSUL
# SUBCUT INSULN
# SUBCUT INSULN P
# SUBCUT KIT
# SUBCUT KIT  MG
# SUBCUT LIQ ER SYR
# SUBCUT P
# SUBCUT PEN
# SUBCUT PEN I
# SUBCUT PEN IJ
# SUBCUT PEN IJ KIT
# SUBCUT PEN IN
# SUBCUT PEN INJ
# SUBCUT PEN INJCTR
# SUBCUT PEN INJCTR
# SUBCUT PEN INJCTR M
# SUBCUT S
# SUBCUT SUSER SYR
# SUBCUT SYR
# SUBCUT SYR W/ IN
# SUBCUT SYRI
# SUBCUT SYRIN
# SUBCUT SYRING
# SUBCUT SYRINGE
# SUBCUT SYRINGE
# SUBCUT SYRINGE  M
# SUBCUT SYRINGE  MG
# SUBCUT SYRINGE  MG/
# SUBCUT SYRINGE .M
# SUBCUT SYRINGE M
# SUBCUT SYRINGE MG
# SUBCUT SYRINGE MG/
# SUBCUT SYRINGEKIT
# SUBCUT V
# SUBCUT VI
# SUBCUT VIA
# SUBCUT VIAL
# SUBCUT VIAL
# SUBCUT VIAL  %
# SUBCUT VIAL  MC
# SUBCUT VIAL  MG
# SUBCUT VIAL  MG/
# SUBCUT VIAL  MG/.M
# SUBCUT VIAL  UNI
# SUBCUT VIAL . MG
# SUBCUT VIAL MG/
# SUBCUT VIAL MG/.
# SUBCUT VIAL MG/M
# SUBCUT WEAR
# SUBCUT WEAR INJCT
# SUBL
# SUBLINGUA
# SUBLINGUAL
# SUBLINGUAL T
# SUBLINGUAL TAB RAP
# SUBLINGUAL TAB S
# SUBLINGUAL TAB SUBL
# SUBLINGUAL TAB SUBL
# T
# T/lactated ringers
# TDF)
# TO
# TOP
# TOPI
# TOPIC
# TOPICA
# TOPICAL
# TOPICAL ADH.
# TOPICAL ADH. P
# TOPICAL ADH. PA
# TOPICAL ADH. PATCH
# TOPICAL ADH. PATCH  %
# TOPICAL ADH. PATCH .
# TOPICAL AER
# TOPICAL AERO
# TOPICAL AERO POWD
# TOPICAL AEROSOL
# TOPICAL B
# TOPICAL BANDA
# TOPICAL BANDAG
# TOPICAL BANDAGE "X
# TOPICAL BAR
# TOPICAL C
# TOPICAL CLE
# TOPICAL CLEAN
# TOPICAL CLEANSE
# TOPICAL CR
# TOPICAL CRE
# TOPICAL CREA
# TOPICAL CREAM
# TOPICAL CREAM (
# TOPICAL CREAM (G
# TOPICAL CREAM (G)
# TOPICAL CREAM (G)
# TOPICAL CREAM (G)  %
# TOPICAL CREAM (G) .
# TOPICAL CREAM PACK
# TOPICAL CREAM(M
# TOPICAL CREAM(ML)  %
# TOPICAL CRM MD PMP
# TOPICAL CRM/PE
# TOPICAL DROP
# TOPICAL DROP W/APP
# TOPICAL EACH
# TOPICAL EM
# TOPICAL FOAM
# TOPICAL FOAM
# TOPICAL FOAM  %
# TOPICAL FOAM .
# TOPICAL FOAM . %
# TOPICAL G
# TOPICAL GEL
# TOPICAL GEL (
# TOPICAL GEL (G
# TOPICAL GEL (GR
# TOPICAL GEL (GRA
# TOPICAL GEL (GRAM
# TOPICAL GEL (GRAM)
# TOPICAL GEL (GRAM)
# TOPICAL GEL (GRAM)  %
# TOPICAL GEL (GRAM)  P
# TOPICAL GEL (GRAM) .
# TOPICAL GEL (ML)
# TOPICAL GEL (ML)  %
# TOPICAL GEL ER(ML)
# TOPICAL GEL W/PU
# TOPICAL GEL W/PUMP
# TOPICAL GEL W/PUMP .
# TOPICAL JEL
# TOPICAL JELLY
# TOPICAL K
# TOPICAL KT SHM
# TOPICAL L
# TOPICAL LIQ-FIL
# TOPICAL LIQU
# TOPICAL LIQUI
# TOPICAL LIQUID
# TOPICAL LIQUID  %
# TOPICAL LIQUID . %
# TOPICAL LO
# TOPICAL LOT
# TOPICAL LOTIO
# TOPICAL LOTION
# TOPICAL LOTION
# TOPICAL LOTION  %
# TOPICAL LOTION .
# TOPICAL LOTION . %
# TOPICAL M
# TOPICAL MED. PA
# TOPICAL MED. PAD
# TOPICAL MED. SWA
# TOPICAL MED. T
# TOPICAL OIL
# TOPICAL OIL  %
# TOPICAL OIN
# TOPICAL OINT
# TOPICAL OINT P
# TOPICAL OINT PACK
# TOPICAL OINT.
# TOPICAL OINT. (
# TOPICAL OINT. (G
# TOPICAL OINT. (G)
# TOPICAL OINT. (G)
# TOPICAL OINT. (G)  %
# TOPICAL OINT. (G) .
# TOPICAL P
# TOPICAL PACK
# TOPICAL PACKE
# TOPICAL PACKET
# TOPICAL PAST
# TOPICAL PASTE (ML)  %
# TOPICAL POW
# TOPICAL POWDER
# TOPICAL POWDER
# TOPICAL POWDER  %
# TOPICAL POWDER . %
# TOPICAL S
# TOPICAL SHA
# TOPICAL SHAMP
# TOPICAL SHAMPO
# TOPICAL SHAMPOO
# TOPICAL SHAMPOO
# TOPICAL SHAMPOO  %
# TOPICAL SHAMPOO . %
# TOPICAL SO
# TOPICAL SOL
# TOPICAL SOL W/AP
# TOPICAL SOL W/APPL
# TOPICAL SOL-FIL
# TOPICAL SOLN
# TOPICAL SOLU
# TOPICAL SOLUTI
# TOPICAL SOLUTIO
# TOPICAL SOLUTION
# TOPICAL SOLUTION
# TOPICAL SOLUTION  %
# TOPICAL SOLUTION .
# TOPICAL SP
# TOPICAL SPIRIT
# TOPICAL SPR
# TOPICAL SPRA
# TOPICAL SPRAY
# TOPICAL SPRAY
# TOPICAL SPRAY  %
# TOPICAL SPRAY/PUMP
# TOPICAL STRIP .
# TOPICAL SUS
# TOPICAL SUSPENSION .
# TOPICAL T
# TOPICAL TAPE "
# TOPICAL TAPE "X
# TOPICAL TIN
# TOPICAL TINCTURE
# TOPICAL VIAL
# TRANS
# TRANSDERM
# TRANSDERM CR
# TRANSDERM CRE
# TRANSDERM GEL (GR
# TRANSDERM GEL MD
# TRANSDERM GEL MD PMP
# TRANSDERM GEL PAC
# TRANSDERM GEL PACKET
# TRANSDERM OINT.
# TRANSDERM PA
# TRANSDERM PATC
# TRANSDERM PATCH
# TRANSDERM PATCH DYSQ
# TRANSDERM PATCH T
# TRANSDERM PATCH TD
# TRANSDERM PATCH TDS
# TRANSDERM PATCH TDSW
# TRANSDERM PATCH TDWK
# TRANSDERM SOL MD
# TRANSDERM SPRAY .
# TRANSLING SPRAY
# U-,ndl,.mL
# URE
# URETHRAL
# URETHRAL SUPP.URET
# V
# V potassium ORAL SO
# V potassium ORAL TA
# VAGIN
# VAGINAL
# VAGINAL C
# VAGINAL CMB
# VAGINAL CRE
# VAGINAL CREAM/APP
# VAGINAL CREAM/APPL
# VAGINAL CREAM/APPL
# VAGINAL CRM
# VAGINAL GEL W/AP
# VAGINAL GEL/PF AP
# VAGINAL INSERT  MC
# VAGINAL INSERT  MCG
# VAGINAL INSERT ER
# VAGINAL INSR DS PK
# VAGINAL KIT
# VAGINAL OIN/PF APP
# VAGINAL SOLUTI
# VAGINAL SUP
# VAGINAL SUPP.VAG
# VAGINAL TABLET  MC
# VAGINAL VAG
# VAGINAL VAG RING .
# VI polysacch vaccine I
# VIIa,recomb
# VIIa,recomb-jncw I
# VWF INTR
# Willebrand factor INTRAVEN
# Xa,inactivated-zhzo INT
# XIII A-subunit,recomb I
# XIII INTRAVEN VIAL
# 1580
